# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split

data = pd.read_csv("subtitles_final_cleanTEST.csv")


# X_train, X_test, y_train, y_test 
#     = train_test_split(X, y, test_size=0.2, random_state=1)

#  X_train, X_val, y_train, y_val 
#     = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

train, test = train_test_split(data, test_size=0.3, random_state=1)

train, dev = train_test_split(train, test_size=0.1,random_state=1)

# train.to_csv("trainingSubs.csv", index=False)
# dev.to_csv("devSubs.csv", index=False)
# test.to_csv("testSubs.csv", index=False)
